# %%
import sys
sys.path.append('C:/Users/royer/Documents/ProyectoFinalModelado/scr')

from solver_fd import temp_chapa_P, temp_chapa_P2, temp_chapa_P3
from utils import graficarChapa, comparar_T

# %%
cond_contor = {'A':1000,'B':-1000,'C':0,'D':0}

typ_cond_contorno = {'A':'temp','B':'temp','C':'temp','D':'temp'}

Nx = 50
Ny = 50
dx = 0.05
dy = 0.05
k = 205     #   Material considerado

hot_point = {'i': 20, 'j': 15, 'T': 200}

T = temp_chapa_P(cond_contor, Nx, Ny, typ_cond_contorno, dx, dy, k, hot_point)

graficarChapa(T,Nx,Ny)

T2 = temp_chapa_P2(cond_contor, Nx, Ny, typ_cond_contorno, dx, dy, k, hot_point)

graficarChapa(T2,Nx,Ny)

# %%
comparar_T(T, T2, Nx, Ny, etiquetas=('Versión Original', 'Versión Optimizada'))
# Out:
# Comparación de distribuciones:
# Diferencia máxima: 0.0000 °C
# Diferencia media:  0.0000 °C
# Desvío estándar:   0.0000 °C
