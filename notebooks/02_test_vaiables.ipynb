# %%
from pathlib import Path
import sys

BASE_DIR = Path().resolve()
sys.path.append(str(BASE_DIR.parent / 'scr'))

from dataset_generator import variables, generar_dataset
from solver_fd import temp_chapa_P, temp_chapa_P2
from utils import graficarChapa, mostrar_tabla_variables_ordenada
#   Valores fijos para el programa 

Nx = 50
Ny = 50
dx = 0.05
dy = 0.05

cond_contor, typ_cond_contorno, hot_point, k, material_nombre,T_fusion=variables(50,50)

T = temp_chapa_P(cond_contor, Nx, Ny, typ_cond_contorno, dx, dy, k, hot_point)

mostrar_tabla_variables_ordenada(cond_contor, typ_cond_contorno, hot_point, material_nombre)

graficarChapa(T,Nx,Ny)
# Out:
# === Condiciones de Contorno ===
# +---------+---------------------+-----------+
# | Borde   | Tipo de condición   |     Valor |
# +=========+=====================+===========+
# | A       | temp                |   -55.826 |
# +---------+---------------------+-----------+
# | B       | flu                 | -9791.95  |
# +---------+---------------------+-----------+
# | C       | flu                 | -2243.94  |
# +---------+---------------------+-----------+
# | D       | temp                |  -129.438 |
# +---------+---------------------+-----------+
#
# === Punto Caliente ===
# +-----+-----+----------+
# |   i |   j |     Temp |
# +=====+=====+==========+
# |  19 |   0 | -183.314 |
# +-----+-----+----------+
#
# Material: Rubidium
