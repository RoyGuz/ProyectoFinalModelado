# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from dataset_generator import generar_dataset_old
from utils import graficar_histograma_temp

Nx = 50
Ny = 50
dx = 0.05
dy = 0.05

#generar_dataset_old(10000, Nx, Ny, dx, dy,'dataset_10000_test_old')
graficar_histograma_temp('dataset_100000_test_old')

graficar_histograma_temp('dataset_100000_test')
# Out:
# Estadísticas generales de dataset_100000_test_old:
# Temperatura mínima: -249.89 °C
# Temperatura máxima: 1398.55 °C
# Temperatura media: 153.87 °C
# Temperatura std: 235.51
# Estadísticas generales de dataset_100000_test:
# Temperatura mínima: -249.98 °C
# Temperatura máxima: 3411.75 °C
# Temperatura media: 542.51 °C
# Temperatura std: 514.39
