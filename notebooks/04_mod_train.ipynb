# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from entrenamiento4 import entrenar_modelo

datasets = ['200000']

epochs = 1000
batch_size = 64
lr = 1e-3
radio = 1
alfa = 0.025

for ds in datasets:

    X_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_train.npy'
    Y_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_train.npy'

    X_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_val.npy'
    Y_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_val.npy'

    subfolder_name = f'MLP_{ds}_test_run00019'

    print(f'Entrenando en dataset {ds}...')
    entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr, radio, alfa)
    #entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr)
    print(f'Finalizado entrenamiento en dataset {ds}.\n')
# Out:
# Entrenando en dataset 200000...
# Epoch 0, Loss: 0.216220, Val_Loss: 0.063337
# Epoch 50, Loss: 0.004617, Val_Loss: 0.006051
# EarlyStopping: 10/100 sin mejora (best_loss=0.005399)
# EarlyStopping: 20/100 sin mejora (best_loss=0.005399)
# Epoch 100, Loss: 0.003358, Val_Loss: 0.004792
# EarlyStopping: 10/100 sin mejora (best_loss=0.004650)
# EarlyStopping: 10/100 sin mejora (best_loss=0.004340)
# EarlyStopping: 20/100 sin mejora (best_loss=0.004340)
# Epoch 150, Loss: 0.002941, Val_Loss: 0.004966
# EarlyStopping: 30/100 sin mejora (best_loss=0.004340)
# EarlyStopping: 40/100 sin mejora (best_loss=0.004340)
# EarlyStopping: 50/100 sin mejora (best_loss=0.004340)
# EarlyStopping: 60/100 sin mejora (best_loss=0.004340)
# EarlyStopping: 10/100 sin mejora (best_loss=0.004151)
# Epoch 200, Loss: 0.002809, Val_Loss: 0.005790
# EarlyStopping: 20/100 sin mejora (best_loss=0.004151)
# EarlyStopping: 30/100 sin mejora (best_loss=0.004151)
# EarlyStopping: 40/100 sin mejora (best_loss=0.004151)
# ...

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))
from utils import compararLossMN


# subfolder_list = ['MLP_1000_test_run00011','MLP_5000_test_run00011','MLP_50000_test_run00011','MLP_100000_test_run00011','MLP_200000_test_run00011']
# lista_nombres = ['MLP - 1000','MLP - 5000','MLP - 50000','MLP - 100000','MLP - 200000']

# subfolder_list = ['MLP_100000_test_run00015','MLP_100000_test_run00016','MLP_100000_test_run00017','MLP_100000_test_run00018','MLP_100000_test_run00019']
# lista_nombres = ['MLP - 100000 R0.3','MLP - 100000 R0.2','MLP - 100000 R0.1','MLP - 100000 R0.05','MLP - 100000 R0.025']

# subfolder_list = ['MLP_100000_test_run00015','MLP_100000_test_run00018','MLP_100000_test_run00019']
# lista_nombres = ['MLP - 100000 R0.3','MLP - 100000 R0.05','MLP - 100000 R0.025']

subfolder_list = ['MLP_100000_test_run00019','MLP_200000_test_run00019']
lista_nombres = ['MLP - 100000 R0.025','MLP - 200000 R0.025']

subfolder_list = ['MLP_100000_test_run00019','MLP_100000_test_run00019R']
lista_nombres = ['MLP - 100000 R0.025 - Ventana','MLP - 100000 R0.025 - Cruz']

compararLossMN(
    subfolder_list,
    aux = 5,
    ylimits=None,
    xlimits=(-10,310),
    radio=True,
    desnormalizar=True,
    usar_rmse=True,
    titulo=False,
    lista_nombres = lista_nombres,
    titulo_figura = None
)
# Out:
# 📈 MLP_100000_test_run00019 | Resto - Val | RMSE final: 28.6436
# 📈 MLP_100000_test_run00019 | RADIO - Val | RMSE final: 120.0425
# 📈 MLP_100000_test_run00019R | Resto - Val | RMSE final: 28.7412
# 📈 MLP_100000_test_run00019R | RADIO - Val | RMSE final: 146.4111
