# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from entrenamiento3 import entrenar_modelo

datasets = ['100000']

epochs = 1000
batch_size = 64
lr = 1e-4

for ds in datasets:

    X_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test_old' / 'X_train.npy'
    Y_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test_old' / 'Y_train.npy'

    X_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test_old' / 'X_val.npy'
    Y_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test_old' / 'Y_val.npy'

    subfolder_name = f'MLP_{ds}_test_old_run04'

    print(f'Entrenando en dataset {ds}...')
    entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr)
    print(f'Finalizado entrenamiento en dataset {ds}.\n')
# Out:
# Entrenando en dataset 100000...
# Epoch 0, Loss: 0.403069, Val_Loss: 0.162341
# Epoch 50, Loss: 0.001163, Val_Loss: 0.001567
# EarlyStopping: 10/150 sin mejora (best_loss=0.001230)
# EarlyStopping: 10/150 sin mejora (best_loss=0.000955)
# Epoch 100, Loss: 0.000566, Val_Loss: 0.000950
# EarlyStopping: 10/150 sin mejora (best_loss=0.000684)
# EarlyStopping: 20/150 sin mejora (best_loss=0.000684)
# EarlyStopping: 30/150 sin mejora (best_loss=0.000684)
# Epoch 150, Loss: 0.000371, Val_Loss: 0.000837
# EarlyStopping: 10/150 sin mejora (best_loss=0.000544)
# EarlyStopping: 20/150 sin mejora (best_loss=0.000544)
# EarlyStopping: 30/150 sin mejora (best_loss=0.000544)
# EarlyStopping: 40/150 sin mejora (best_loss=0.000544)
# Epoch 200, Loss: 0.000281, Val_Loss: 0.000573
# EarlyStopping: 10/150 sin mejora (best_loss=0.000462)
# EarlyStopping: 10/150 sin mejora (best_loss=0.000451)
# EarlyStopping: 20/150 sin mejora (best_loss=0.000451)
# EarlyStopping: 30/150 sin mejora (best_loss=0.000451)
# ...

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import validar_modelo

folder_data = 'dataset_100000_test_old'
folder_results = 'MLP_100000_test_old_run04'

validar_modelo(folder_data,folder_results,'val',idx_muestra=None,mostrar=False,escala=False,hotPoint=None)
# Out:
# Tiempo de calculo con ML: 0.001187 segundos
# Tiempo de cálculo con MDF_1 (temp_chapa_P): 0.239091 segundos
# Tiempo de cálculo con MDF_2 (temp_chapa_P): 0.240423 segundos
#
# Se muestra la muestra con índice: 23734
#
# Comparación de distribuciones:
# Diferencia máxima: 10.7325 °C
# Diferencia media:  4.6700 °C
# Desvío estándar:   2.3079 °C
# Hola

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))
from utils import compararLoss, compararLossM


subfolder_list = ['MLP_100000_test_old_run04']
compararLossM(subfolder_list,0,(None,None),(None,None),radio=False)
