# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from entrenamiento3 import entrenar_modelo
from utils import plot_rmse_losses_single

datasets = ['100000']

epochs = 2000
batch_size = 32
lr = 1e-4
# radio = 10
# alfa = 0.99

for ds in datasets:

    X_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_train.npy'
    Y_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_train.npy'

    X_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_val.npy'
    Y_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_val.npy'

    subfolder_name = f'MLP_{ds}_test_run02'

    print(f'Entrenando en dataset {ds}...')
    #entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr, radio, alfa)
    entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr)
    print(f'Finalizado entrenamiento en dataset {ds}.\n')
# Out:
# Entrenando en dataset 100000...
# Epoch 0, Loss: 0.609015, Val_Loss: 0.386396
# Epoch 50, Loss: 0.009078, Val_Loss: 0.013714
# Epoch 100, Loss: 0.004767, Val_Loss: 0.007549
# Epoch 150, Loss: 0.003479, Val_Loss: 0.006705
# Epoch 200, Loss: 0.002826, Val_Loss: 0.005057
# Epoch 250, Loss: 0.002465, Val_Loss: 0.005343
# Epoch 300, Loss: 0.002207, Val_Loss: 0.004639
# Epoch 350, Loss: 0.002061, Val_Loss: 0.003942
# Epoch 400, Loss: 0.001893, Val_Loss: 0.004033
# Epoch 450, Loss: 0.001806, Val_Loss: 0.003684
# Epoch 500, Loss: 0.001688, Val_Loss: 0.004403
# Epoch 550, Loss: 0.001621, Val_Loss: 0.003674
# Epoch 600, Loss: 0.001531, Val_Loss: 0.003408
# Epoch 650, Loss: 0.001469, Val_Loss: 0.003363
# Epoch 700, Loss: 0.001425, Val_Loss: 0.003617
# Epoch 750, Loss: 0.001392, Val_Loss: 0.003109
# Epoch 800, Loss: 0.001361, Val_Loss: 0.002920
# Epoch 850, Loss: 0.001318, Val_Loss: 0.003065
# Epoch 900, Loss: 0.001267, Val_Loss: 0.003172
# Epoch 950, Loss: 0.001244, Val_Loss: 0.002992
# ...

# %%
# from pathlib import Path
# BASE_DIR = Path().resolve()
# import sys
# sys.path.append(str(BASE_DIR.parent / 'scr'))

# from entrenamiento4 import entrenar_modelo
# from utils import plot_rmse_losses_single

# BASE_DIR = Path().resolve()
# save_folder = BASE_DIR.parent / 'results' / 'MLP_5000_test_run001'

# plot_rmse_losses_single(
#     save_folder,
#     loss_type='todos',       # 'global', 'radio', 'resto', 'todos'
#     unidades_fisicas=False    # True = en °C, False = normalizado

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import compararLoss

subfolder_name_1 = "MLP_100000_test_run03"
subfolder_name_2 = "MLP_100000_test_run02"

compararLoss(subfolder_name_1,subfolder_name_2,0)

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import validar_modelo

folder_data = 'dataset_100000_test'
folder_results = 'MLP_100000_test_run02'
#folder_results = 'MLP_100000_test_run03'

validar_modelo(folder_data,folder_results,'train',idx_muestra=None,mostrar=False)
# Out:
# Tiempo de calculo con ML: 0.000842 segundos
# Tiempo de cálculo con MDF_1 (temp_chapa_P): 0.233324 segundos
# Tiempo de cálculo con MDF_2 (temp_chapa_P): 0.230629 segundos
#
# Se muestra la muestra con índice: 10608
#
# Comparación de distribuciones:
# Diferencia máxima: 21.1116 °C
# Diferencia media:  4.4331 °C
# Desvío estándar:   3.0380 °C

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))
from utils import compararLoss, compararLossM


datasets = ['05', '06','08','09','10']
radios = ['radio = 1', 'radio = 2', 'radio = 3', 'radio = 4', 'radio = 5' ]

#datasets = ['05']

subfolder_list = []

for ds in datasets:
    subfolder_list.append(f'MLP_5000_test_run{ds}')

compararLossM(subfolder_list,radios, 2,(None,None),(None,None))
