# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from entrenamiento4 import entrenar_modelo

datasets = ['100000']

epochs = 1000
batch_size = 32
lr = 1e-4
radio = 1
alfa = 0.3

for ds in datasets:

    X_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_train.npy'
    Y_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_train.npy'

    X_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'X_val.npy'
    Y_val_path = BASE_DIR.parent / 'data' / f'dataset_{ds}_test' / 'Y_val.npy'

    subfolder_name = f'MLP_{ds}_test_run12'

    print(f'Entrenando en dataset {ds}...')
    entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr, radio, alfa)
    #entrenar_modelo(X_path, Y_path, X_val_path, Y_val_path, subfolder_name, epochs, batch_size, lr)
    print(f'Finalizado entrenamiento en dataset {ds}.\n')
# Out:
# Entrenando en dataset 100000...
# Epoch 0, Loss: 0.516265, Val_Loss: 0.395302
# Epoch 50, Loss: 0.020758, Val_Loss: 0.033465
# Epoch 100, Loss: 0.014686, Val_Loss: 0.025552
# Epoch 150, Loss: 0.012327, Val_Loss: 0.023310
# Epoch 200, Loss: 0.011019, Val_Loss: 0.022773
# EarlyStopping: 20/200 sin mejora (best_loss=0.022472)
# EarlyStopping: 20/200 sin mejora (best_loss=0.022048)
# Epoch 250, Loss: 0.010104, Val_Loss: 0.021999
# EarlyStopping: 40/200 sin mejora (best_loss=0.022048)
# EarlyStopping: 20/200 sin mejora (best_loss=0.021680)
# Epoch 300, Loss: 0.009485, Val_Loss: 0.021817
# EarlyStopping: 40/200 sin mejora (best_loss=0.021680)
# EarlyStopping: 20/200 sin mejora (best_loss=0.021546)
# Epoch 350, Loss: 0.009002, Val_Loss: 0.022205
# EarlyStopping: 20/200 sin mejora (best_loss=0.021388)
# EarlyStopping: 20/200 sin mejora (best_loss=0.021170)
# Epoch 400, Loss: 0.008635, Val_Loss: 0.021515
# EarlyStopping: 40/200 sin mejora (best_loss=0.021170)
# EarlyStopping: 20/200 sin mejora (best_loss=0.020927)
# Epoch 450, Loss: 0.008308, Val_Loss: 0.021159
# EarlyStopping: 40/200 sin mejora (best_loss=0.020927)
# EarlyStopping: 60/200 sin mejora (best_loss=0.020927)
# EarlyStopping: 80/200 sin mejora (best_loss=0.020927)
# Epoch 500, Loss: 0.008024, Val_Loss: 0.020993
# EarlyStopping: 20/200 sin mejora (best_loss=0.020802)
# EarlyStopping: 20/200 sin mejora (best_loss=0.020608)
# Epoch 550, Loss: 0.007775, Val_Loss: 0.020897
# EarlyStopping: 40/200 sin mejora (best_loss=0.020608)
# EarlyStopping: 60/200 sin mejora (best_loss=0.020608)
# Epoch 600, Loss: 0.007548, Val_Loss: 0.021106
# EarlyStopping: 80/200 sin mejora (best_loss=0.020608)
# EarlyStopping: 20/200 sin mejora (best_loss=0.020453)
# Epoch 650, Loss: 0.007355, Val_Loss: 0.020654
# EarlyStopping: 40/200 sin mejora (best_loss=0.020453)
# EarlyStopping: 20/200 sin mejora (best_loss=0.020350)
# Epoch 700, Loss: 0.007205, Val_Loss: 0.020375
# EarlyStopping: 40/200 sin mejora (best_loss=0.020350)
# EarlyStopping: 20/200 sin mejora (best_loss=0.020205)
# Epoch 750, Loss: 0.007050, Val_Loss: 0.020310
# EarlyStopping: 20/200 sin mejora (best_loss=0.020092)
# Epoch 800, Loss: 0.006912, Val_Loss: 0.020225
# EarlyStopping: 40/200 sin mejora (best_loss=0.020092)
# EarlyStopping: 20/200 sin mejora (best_loss=0.019987)
# Epoch 850, Loss: 0.006793, Val_Loss: 0.019943
# EarlyStopping: 40/200 sin mejora (best_loss=0.019987)
# EarlyStopping: 60/200 sin mejora (best_loss=0.019987)
# Epoch 900, Loss: 0.006653, Val_Loss: 0.020058
# EarlyStopping: 20/200 sin mejora (best_loss=0.019847)
# EarlyStopping: 40/200 sin mejora (best_loss=0.019847)
# EarlyStopping: 60/200 sin mejora (best_loss=0.019847)
# Epoch 950, Loss: 0.006552, Val_Loss: 0.019746
# EarlyStopping: 20/200 sin mejora (best_loss=0.019746)
# EarlyStopping: 40/200 sin mejora (best_loss=0.019746)
# Epoch 999, Loss: 0.006468, Val_Loss: 0.019998
# Se creó la carpeta: C:\Users\royer\Documents\ProyectoFinalModelado\results\MLP_100000_test_run11
# Entrenamiento completado. Modelo guardado en C:\Users\royer\Documents\ProyectoFinalModelado\results\MLP_100000_test_run11\model_train.pt
# Finalizado entrenamiento en dataset 100000.

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import compararLoss

subfolder_name_1 = "MLP_50000_test_run11"
subfolder_name_2 = "MLP_100000_test_run11"

compararLoss(subfolder_name_1,subfolder_name_2,0)

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import validar_modelo

folder_data = 'dataset_100000_test'
folder_results = 'MLP_100000_test_run11'
#folder_results = 'MLP_100000_test_run03'

validar_modelo(folder_data,folder_results,'train',idx_muestra=49320,mostrar=True,escala=False)
# Out:
# Tiempo de calculo con ML: 0.001603 segundos
# Tiempo de cálculo con MDF_1 (temp_chapa_P): 0.708673 segundos
# Tiempo de cálculo con MDF_2 (temp_chapa_P): 0.679680 segundos
#
# Se muestra la muestra con índice: 49320
#
# === Condiciones de Contorno ===
# +---------+---------------------+-----------+
# | Borde   | Tipo de condición   |     Valor |
# +=========+=====================+===========+
# | A       | temp                |   437.454 |
# +---------+---------------------+-----------+
# | B       | flu                 | -7318.61  |
# +---------+---------------------+-----------+
# | C       | flu                 | -4520.02  |
# +---------+---------------------+-----------+
# | D       | flu                 | -2627.14  |
# +---------+---------------------+-----------+
#
# === Punto Caliente ===
# +-----+-----+---------+
# |   i |   j |    Temp |
# +=====+=====+=========+
# |  46 |  12 | 586.216 |
# +-----+-----+---------+
#
# Material: Silicon
#
# Comparación de distribuciones:
# Diferencia máxima: 97.5045 °C
# Diferencia media:  17.2667 °C
# Desvío estándar:   13.5396 °C

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))
from utils import compararLoss, compararLossM


subfolder_list = ['MLP_5000_test_run0002','MLP_5000_test_run0006','MLP_100000_test_run11']
compararLossM(subfolder_list,5,(None,None),(None,None),radio=True)

# %%
from pathlib import Path
BASE_DIR = Path().resolve()
import sys
sys.path.append(str(BASE_DIR.parent / 'scr'))

from utils import compararModelos

folder_data = 'dataset_100000_test'
folder_resultsM = ['MLP_100000_test_run11','MLP_100000_test_run03']

compararModelos(folder_data,folder_resultsM,'train',idx_muestra=None,mostrar=False,auto=True)
# Out:
# Se muestra la muestra con índice: 24194
#
# Comparación de distribuciones - MLP_100000_test_run11
# Diferencia máxima: 292.7571 °C  -  Diferencia media:  37.8108 °C  -  Desvío estándar:   32.7817 °C
#
# Comparación de distribuciones - MLP_100000_test_run03
# Diferencia máxima: 629.3751 °C  -  Diferencia media:  10.0100 °C  -  Desvío estándar:   23.7448 °C
